# %%
from pandas import *
import sys
path = '/Users/jplotkin/Dropbox/school/adv_ml'
path += '/project/scripts_notebooks'
sys.path.append(path)

from prep_datasets import *
from train_cv_predict import *
plt.style.use('ggplot')

# %load_ext autotime
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2

# %% [markdown]
# ### Load data
# * image features from CNN
# * metadata

# %%
data_path = '../boots_dataset/'
metadata_women = read_csv(data_path + 'boots_aws_metadata_160405.csv',
                         index_col = 'asin')
metadata_women = metadata_women[metadata_women.sex == 'women']
features_women = read_csv(data_path + 'features_women.csv',
                         index_col = 'asin')
# Out:
# time: 3.27 s

# %%
path = '/Users/jplotkin/Dropbox/school/adv_ml/'
path += 'project/ImageRec/data/test_likes_josh.txt'
likes_dislikes = read_csv(path, 
                 header = None)\
                    .drop_duplicates()\
                    .set_index(0, inplace = False)
likes_dislikes.index.name = 'asin'
likes_dislikes.columns = ['like']
# Out:
# time: 25.7 ms

# %%
likes_dislikes.merge(metadata_women, left_index = True, 
                    right_index = True).merge(features_women, left_index = True, 
                           right_index = True).like.value_counts()
# Out:
# 0    127
# 1     33
# Name: like, dtype: int64
# time: 46.8 ms

# %%
likes = likes_dislikes.merge(metadata_women, left_index = True, 
                    right_index = True).merge(features_women, left_index = True, 
                           right_index = True).like
# Out:
# time: 42.7 ms

# %% [markdown]
# ### PrepData class
# * balance dataset by oversampling
# * perform stratified sampling to split data
# * takes list of size of training set (the rest go into test)
# * creates a feature set of unlabeled data (for recommendations)

# %%
dataset = PrepData(DataFrame(likes), features_women, 
                   [10, 25, 50, 80], 5, False)
# Out:
# 10 0.9375
# 10 150
# 10 150
# 10 150
# 10 150
# 10 150
# 25 0.84375
# 25 135
# 25 135
# 25 135
# 25 135
# 25 135
# 50 0.6875
# 50 110
# 50 110
# 50 110
# 50 110
# 50 110
# 80 0.5
# 80 80
# 80 80
# 80 80
# 80 80
# 80 80
# time: 20.6 s

# %%
print dataset.training_sets.keys()
print dataset.test_sets.keys()
# Out:
# [80, 25, 10, 50]
# [80, 25, 10, 50]
# time: 28.3 ms

# %%
dataset.training_sets[50][0].like.value_counts()
# Out:
# 0    40
# 1    10
# Name: like, dtype: int64
# time: 30.4 ms

# %%
dataset.training_sets[50][0].drop_duplicates().like.value_counts()
# Out:
# 0    40
# 1    10
# Name: like, dtype: int64
# time: 279 ms

# %%
dataset.test_sets[50][0].like.value_counts()
# Out:
# 0    87
# 1    23
# Name: like, dtype: int64
# time: 32.3 ms

# %%
dataset.test_sets[50][0].drop_duplicates().like.value_counts()
# Out:
# 0    87
# 1    23
# Name: like, dtype: int64
# time: 302 ms

# %%
asin_in = []
for asin in dataset.test_sets[50][0].index:
    asin_in.append(asin in dataset.training_sets[50][0])
print sum(asin_in)
# Out:
# 0
# time: 30.2 ms

# %% [markdown]
# ### TrainModel class
# TrainModel(train, test, algo, grid params, nfolds)
# * performs grid search automatically using params and number of folds
# * returns best model
# * include methods to get AUC, plot ROC, and show top n recommendations
# * TODO: implement XGBoost grid search

# %%
training_set = dataset.training_sets[80][0]
test_set = dataset.test_sets[80][0]
unlabeled = dataset.unlabeled
# Out:
# time: 27.7 ms

# %% [markdown]
# ### XGBoost:

# %%
# num_round=2

# def fpreproc(dtrain, dtest, param):
#     label = dtrain.get_label()
#     ratio = float(np.sum(label == 0)) / np.sum(label==1)
#     param['scale_pos_weight'] = ratio
#     return (dtrain, dtest, param)


# xgb.cv(param, training_set.copy(), num_round, nfold=5,
#        metrics={'auc'}, seed = 0, fpreproc = fpreproc)
# Out:
# time: 31.2 ms

# %%
param = {'bst:max_depth':2, 
         'bst:eta':1, 
         'silent':1,
         'objective':'binary:logistic' }
param['nthread'] = 4
param['eval_metric'] = 'auc'
param['eval_metric'] = ['auc']#, 'ams@0'] 

model = TrainModel(training_set.copy(), test_set.copy(), 'xgb', param, 5)
model.get_auc()
model.plot_roc()
model.display_recommendations(unlabeled.copy(), 5)
# Out:
# [0]	train-auc:0.954590
# [1]	train-auc:0.998047
# [2]	train-auc:1.000000
# [3]	train-auc:1.000000
# [4]	train-auc:1.000000
# [5]	train-auc:1.000000
# [6]	train-auc:1.000000
# [7]	train-auc:1.000000
# [8]	train-auc:1.000000
# [9]	train-auc:1.000000
# time: 2.54 s

# %% [markdown]
# ### SVM:

# %%
param_grid = [
  {'C': [10**i for i in np.arange(-7,2,.1)], 
       'kernel': ['linear']},
  {'C': [10**i for i in np.arange(-7,2,.1)], 
       'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]
svm = TrainModel(training_set.copy(), test_set.copy(), 
                   'svm', param_grid, 10)

print svm.get_auc()
svm.report()
svm.plot_roc()
svm.display_recommendations(unlabeled.copy(), 5)
# Out:
# 0.666199813259
# Model with rank: 1
# Mean validation score: 0.850 (std: 0.053)
# Parameters: {'kernel': 'rbf', 'C': 7.9432823472423015, 'gamma': 0.0001}
#
# Model with rank: 2
# Mean validation score: 0.850 (std: 0.053)
# Parameters: {'kernel': 'rbf', 'C': 9.9999999999993463, 'gamma': 0.0001}
#
# Model with rank: 3
# Mean validation score: 0.850 (std: 0.053)
# Parameters: {'kernel': 'rbf', 'C': 12.589254117940838, 'gamma': 0.0001}
# time: 1min 40s

# %% [markdown]
# ### Naive Bayes

# %%
param_grid = [
  {'alpha': [10**i for i in np.arange(-7,2,.1)]}
 ]    
nb = TrainModel(training_set.copy(), test_set.copy(),
                   'nb', param_grid, 10)
nb.get_auc()
nb.report()
nb.plot_roc()
nb.display_recommendations(unlabeled.copy(), 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.850 (std: 0.051)
# Parameters: {'alpha': 0.00099999999999996728}
#
# Model with rank: 2
# Mean validation score: 0.850 (std: 0.061)
# Parameters: {'alpha': 0.0063095734448016848}
#
# Model with rank: 3
# Mean validation score: 0.850 (std: 0.061)
# Parameters: {'alpha': 0.0079432823472424963}
# time: 7.05 s

# %% [markdown]
# ### Random Forest

# %%
param_grid = {"max_depth": [3, 4000],
              "max_features": np.arange(1,4000,200),
              "min_samples_split": np.arange(1,500,100),
              "min_samples_leaf": [100, 50, 25, 10, 5],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}
rf = TrainModel(training_set.copy(), test_set.copy(),
                   'rf', param_grid, 10)

rf.get_auc()
rf.report()
rf.plot_roc()
rf.display_recommendations(unlabeled.copy(), 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.863 (std: 0.088)
# Parameters: {'bootstrap': True, 'min_samples_leaf': 5, 'min_samples_split': 1, 'criterion': 'gini', 'max_features': 2201, 'max_depth': 3}
#
# Model with rank: 2
# Mean validation score: 0.850 (std: 0.089)
# Parameters: {'bootstrap': True, 'min_samples_leaf': 5, 'min_samples_split': 1, 'criterion': 'gini', 'max_features': 1001, 'max_depth': 4000}
#
# Model with rank: 3
# Mean validation score: 0.838 (std: 0.064)
# Parameters: {'bootstrap': True, 'min_samples_leaf': 5, 'min_samples_split': 1, 'criterion': 'gini', 'max_features': 3801, 'max_depth': 3}
# time: 3min 17s

# %% [markdown]
# ### Elastic Net logistic regression

# %%
param_grid = [
        {'alpha': [10**i for i in np.arange(-7,2,1)], 
         'l1_ratio': np.arange(0,1.1,0.1)
        }]

enet = TrainModel(training_set.copy(), test_set.copy(),
                   'lr_enet', param_grid, 10)

enet.get_auc()
enet.report()
enet.plot_roc()
enet.display_recommendations(unlabeled.copy(), 10)
# Out:
# Model with rank: 1
# Mean validation score: 0.738 (std: 0.120)
# Parameters: {'alpha': 10, 'l1_ratio': 0.90000000000000002}
#
# Model with rank: 2
# Mean validation score: 0.725 (std: 0.052)
# Parameters: {'alpha': 0.01, 'l1_ratio': 0.90000000000000002}
#
# Model with rank: 3
# Mean validation score: 0.700 (std: 0.165)
# Parameters: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.10000000000000001}
# time: 11.9 s

# %% [markdown]
# ### Scikit-learn SGD Classifier

# %%
param_grid = [
        {'alpha': [10**i for i in np.arange(-7,2,.1)], 
         'l1_ratio': np.arange(0,1.1,0.1),
         'loss': ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'],
         'class_weight': [{1: 0.75, 0: 0.25}, {1: 0.90, 0: 0.10}]
        }]

enet = TrainModel(training_set.copy(), test_set.copy(),
                   'sgd', param_grid, 2)
enet.get_auc()
enet.report()
enet.plot_roc()
enet.display_recommendations(unlabeled.copy(), 10)
# Out:
# Model with rank: 1
# Mean validation score: 0.863 (std: 0.068)
# Parameters: {'alpha': 9.9999999999999995e-08, 'loss': 'log', 'l1_ratio': 0.0}
#
# Model with rank: 2
# Mean validation score: 0.863 (std: 0.100)
# Parameters: {'alpha': 2.5118864315095514e-06, 'loss': 'squared_hinge', 'l1_ratio': 0.0}
#
# Model with rank: 3
# Mean validation score: 0.863 (std: 0.050)
# Parameters: {'alpha': 0.00019952623149688256, 'loss': 'modified_huber', 'l1_ratio': 1.0}
# time: 5min 57s

# %% [markdown]
# ### Comparison of Online vs. Batch Learning for Scikit-Learn's SGDClassifier

# %% [markdown]
# #### Train in batch

# %%
model = SGDClassifier(alpha = , l1_ratio = , loss = , penalty='elasticnet', 
        fit_intercept=True, n_iter=5, shuffle=True, verbose=0, epsilon=0.1, 
        n_jobs=1, random_state=None, learning_rate='optimal', eta0=0.0, 
        power_t=0.5, class_weight=None, warm_start=False, average=False)

model.fit(training_set.drop('like', axis = 1), training_set.like)

pred_df = DataFrame(zip(model.predict(test_set.drop('like', axis = 1)), test_set.like))
pred_df.columns = 'predicted','actual'
fpr, tpr, _ = roc_curve(pred.actual, 
                        pred.predicted, 
                        pos_label = 1)
roc_auc = auc(fpr, tpr)
print roc_auc

# %% [markdown]
# #### Train incrementally (one)

# %%
model = SGDClassifier(alpha = , l1_ratio = , loss = , penalty='elasticnet', 
        fit_intercept=True, n_iter=5, shuffle=True, verbose=0, epsilon=0.1, 
        n_jobs=1, random_state=None, learning_rate='optimal', eta0=0.0, 
        power_t=0.5, class_weight=None, warm_start=False, average=False)

model.fit(training_set.iloc[0, :].drop('like', axis = 1), training_set.iloc[0, :].like)

# %% [markdown]
# #### Train incrementally (all)

# %%
model = SGDClassifier(alpha = , l1_ratio = , loss = , penalty='elasticnet', 
        fit_intercept=True, n_iter=5, shuffle=True, verbose=0, epsilon=0.1, 
        n_jobs=1, random_state=None, learning_rate='optimal', eta0=0.0, 
        power_t=0.5, class_weight=None, warm_start=False, average=False)

non_like = [c for c in training_set.columns if c != 'like']
for i in training_set.index:
    model.partial_fit(training_set.loc[i, 'non_like'], training_set.loc[i, 'like'])
