# %%
from pandas import *
import sys
path = '/Users/jplotkin/Dropbox/school/adv_ml'
path += '/project/scripts_notebooks'
sys.path.append(path)

from prep_datasets import *
from train_cv_predict import *
plt.style.use('ggplot')

# %load_ext autotime
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# time: 203 ms

# %% [markdown]
# ### Load data
# * image features from CNN
# * metadata

# %%
data_path = '../boots_dataset/'
metadata_women = read_csv(data_path + 'boots_aws_metadata_160405.csv',
                         index_col = 'asin')
metadata_women = metadata_women[metadata_women.sex == 'women']
features_women = read_csv(data_path + 'features_women.csv',
                         index_col = 'asin')
# Out:
# time: 3.13 s

# %%
path = '/Users/jplotkin/Dropbox/school/adv_ml/'
path += 'project/ImageRec/data/test_likes_josh.txt'
likes_dislikes = read_csv(path, 
                 header = None)\
                    .drop_duplicates()\
                    .set_index(0, inplace = False)
likes_dislikes.index.name = 'asin'
likes_dislikes.columns = ['like']
# Out:
# time: 26.8 ms

# %%
likes_dislikes.merge(metadata_women, left_index = True, 
                    right_index = True).merge(features_women, left_index = True, 
                           right_index = True).like.value_counts()
# Out:
# 0    127
# 1     33
# Name: like, dtype: int64
# time: 50.3 ms

# %%
likes = likes_dislikes.merge(metadata_women, left_index = True, 
                    right_index = True).merge(features_women, left_index = True, 
                           right_index = True).like
# Out:
# time: 45.9 ms

# %% [markdown]
# ### PrepData class
# * balance dataset by oversampling
# * perform stratified sampling to split data
# * takes list of size of training set (the rest go into test)
# * creates a feature set of unlabeled data (for recommendations)

# %%
dataset = PrepData(DataFrame(likes), features_women, 
                   [10, 25, 50, 80], 5, True)
# Out:
# 10 0.9375
# 10 150
# 10 150
# 10 150
# 10 150
# 10 150
# 25 0.84375
# 25 135
# 25 135
# 25 135
# 25 135
# 25 135
# 50 0.6875
# 50 110
# 50 110
# 50 110
# 50 110
# 50 110
# 80 0.5
# 80 80
# 80 80
# 80 80
# 80 80
# 80 80
# time: 17.2 s

# %%
print dataset.training_sets.keys()
print dataset.test_sets.keys()
# Out:
# [80, 25, 10, 50]
# [80, 25, 10, 50]
# time: 20.4 ms

# %%
dataset.training_sets[50][0].like.value_counts()
# Out:
# 1    50
# 0    40
# Name: like, dtype: int64
# time: 25.6 ms

# %%
dataset.training_sets[50][0].drop_duplicates().like.value_counts()
# Out:
# 0    40
# 1    10
# Name: like, dtype: int64
# time: 471 ms

# %%
dataset.test_sets[50][0].like.value_counts()
# Out:
# 0    87
# 1    23
# Name: like, dtype: int64
# time: 21.6 ms

# %%
dataset.test_sets[50][0].drop_duplicates().like.value_counts()
# Out:
# 0    87
# 1    23
# Name: like, dtype: int64
# time: 234 ms

# %%
asin_in = []
for asin in dataset.test_sets[50][0].index:
    asin_in.append(asin in dataset.training_sets[50][0])
print sum(asin_in)
# Out:
# 0
# time: 19.9 ms

# %% [markdown]
# ### TrainModel class
# TrainModel(train, test, algo, grid params, nfolds)
# * performs grid search automatically using params and number of folds
# * returns best model
# * include methods to get AUC, plot ROC, and show top n recommendations
# * TODO: implement XGBoost grid search

# %%
training_set = dataset.training_sets[50][0]
test_set = dataset.test_sets[50][0]
unlabeled = dataset.unlabeled
# Out:
# time: 17.7 ms

# %% [markdown]
# ### XGBoost:

# %%
# num_round=2

# def fpreproc(dtrain, dtest, param):
#     label = dtrain.get_label()
#     ratio = float(np.sum(label == 0)) / np.sum(label==1)
#     param['scale_pos_weight'] = ratio
#     return (dtrain, dtest, param)


# xgb.cv(param, training_set.copy(), num_round, nfold=5,
#        metrics={'auc'}, seed = 0, fpreproc = fpreproc)
# Out:
# time: 19.2 ms

# %%
param = {'bst:max_depth':2, 
         'bst:eta':1, 
         'silent':1,
         'objective':'binary:logistic' }
param['nthread'] = 4
param['eval_metric'] = 'auc'
param['eval_metric'] = ['auc']#, 'ams@0'] 

model = TrainModel(training_set.copy(), test_set.copy(), 'xgb', param, 5)
model.get_auc()
model.plot_roc()
model.display_recommendations(unlabeled.copy(), 5)
# Out:
# [0]	train-auc:0.975000
# [1]	train-auc:1.000000
# [2]	train-auc:1.000000
# [3]	train-auc:1.000000
# [4]	train-auc:1.000000
# [5]	train-auc:1.000000
# [6]	train-auc:1.000000
# [7]	train-auc:1.000000
# [8]	train-auc:1.000000
# [9]	train-auc:1.000000
# time: 1.86 s

# %% [markdown]
# ### SVM:

# %%
param_grid = [
  {'C': [10**i for i in np.arange(-7,2,.1)], 
       'kernel': ['linear']},
  {'C': [10**i for i in np.arange(-7,2,.1)], 
       'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]

svm = TrainModel(training_set.copy(), test_set.copy(), 
                   'svm', param_grid, 10)
# Out:
# time: 22.2 s

# %%
print svm.get_auc()
svm.report()
svm.plot_roc()
# svm.plot_cv_roc(5)
svm.display_recommendations(unlabeled.copy(), 5)
# Out:
# 0.5
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'kernel': 'rbf', 'C': 0.63095734448015817, 'gamma': 0.001}
#
# Model with rank: 2
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'kernel': 'rbf', 'C': 0.79432823472423664, 'gamma': 0.001}
#
# Model with rank: 3
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'kernel': 'rbf', 'C': 0.99999999999994271, 'gamma': 0.001}
# time: 1.96 s

# %% [markdown]
# ### Naive Bayes

# %%
param_grid = [
  {'alpha': [10**i for i in np.arange(-7,2,.1)]}
 ]    
nb = TrainModel(training_set.copy(), test_set.copy(),
                   'nb', param_grid, 10)
# Out:
# time: 1.76 s

# %%
nb.get_auc()
nb.report()
nb.plot_roc()
# nb.plot_cv_roc(5)
nb.display_recommendations(unlabeled.copy(), 5)
# Out:
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'alpha': 9.9999999999999995e-08}
#
# Model with rank: 2
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'alpha': 1.2589254117941662e-07}
#
# Model with rank: 3
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'alpha': 1.5848931924611109e-07}
# time: 1.48 s

# %% [markdown]
# ### Random Forest (TODO: fix grid search)

# %%
# import scipy
# param_grid = {"max_depth": [3, 4000],
#               "max_features": sp_randint(1, 4000),
#               "min_samples_split": sp_randint(1, 500),
#               "min_samples_leaf": scipy.stats.expon(scale=100),
#               "bootstrap": [True, False],
#               "criterion": ["gini", "entropy"]}
# rf = TrainModel(training_set.copy(), test_set.copy(),
#                    'rf', param_grid, 10)
# Out:
# time: 18.3 ms

# %%
# rf.get_auc()
# rf.report()
# rf.plot_roc()
# rf.plot_cv_roc(5)
# rf.display_recommendations(unlabeled.copy(), 5)
# Out:
# time: 23.2 ms

# %% [markdown]
# ### Elastic Net logistic regression

# %%
param_grid = [
        {'alpha': [10**i for i in np.arange(-7,2,1)], 
         'l1_ratio': np.arange(0,1.1,0.1)
        }]

enet = TrainModel(training_set.copy(), test_set.copy(),
                   'lr_enet', param_grid, 2)
# Out:
# time: 2.72 s

# %%
enet.get_auc()
enet.report()
enet.plot_roc()
enet.display_recommendations(unlabeled.copy(), 10)
# Out:
# Model with rank: 1
# Mean validation score: 0.689 (std: 0.044)
# Parameters: {'alpha': 10, 'l1_ratio': 0.20000000000000001}
#
# Model with rank: 2
# Mean validation score: 0.667 (std: 0.022)
# Parameters: {'alpha': 0.0001, 'l1_ratio': 0.5}
#
# Model with rank: 3
# Mean validation score: 0.667 (std: 0.111)
# Parameters: {'alpha': 0.001, 'l1_ratio': 0.30000000000000004}
# time: 1.61 s

# %%
enet = TrainModel(training_set.copy(), test_set.copy(),
                   'lr_enet', param_grid, 2)
# Out:
# time: 2.9 s

# %%
enet.get_auc()
enet.report()
enet.plot_roc()
enet.display_recommendations(unlabeled.copy(), 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.678 (std: 0.122)
# Parameters: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.10000000000000001}
#
# Model with rank: 2
# Mean validation score: 0.667 (std: 0.089)
# Parameters: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.0}
#
# Model with rank: 3
# Mean validation score: 0.644 (std: 0.089)
# Parameters: {'alpha': 0.001, 'l1_ratio': 0.70000000000000007}
# time: 1 s
